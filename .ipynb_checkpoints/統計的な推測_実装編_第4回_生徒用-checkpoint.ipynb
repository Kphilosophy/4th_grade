# %% [markdown]
# # 必要なモジュールのインポート

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # 仮説検定の考え方
#
# ## 例題 1
#
# コインを$20$枚投げたところ，そのうち$15$回で表が出た．
# この結果から，このコインは（例えば歪みや細工により）裏よりも表が出やすいと判断してよいだろうか．
# $$
# H_0 \colon p = 0.5 \\
# H_1 \colon p \neq 0.5
# $$
# として，有意水準$5\%$で両側検定したい．
# どのような計算を行えばよいか，下のセルにコードを書け．
#
# ##### ヒント
#
# 二項分布$B(N,p)$の累積分布関数$F(t) = P(X \leqq t)$は，次のコードが利用できる．
# ```
# stats.binom.cdf(t, N, p)
# ```

# %%
# ここにコードを書く
if 1 - stats.binom.cdf(15-1,20,0.5) > 0.025:
    print("コイントスで15回以上表が出る確率は{:.3f}であり，有意水準5%でH_0は棄却されない".format(1 - stats.binom.cdf(15-1,20,0.5)))
else:
    print("コイントスで15回以上表が出る確率は{:.3f}であり，有意水準5%でH_0は棄却される".format(1 - stats.binom.cdf(15-1,20,0.5)))
# Out:
# コイントスで15回以上表が出る確率は0.021であり，有意水準5%でH_0は棄却される

# %% [markdown]
# ## 例題 1
#
# 表が出やすくなるように，コインの片面に細工を施した．
# このコインを$20$枚投げたところ，そのうち$14$回で表が出た．
# この結果から，このコインは裏よりも表が出やすくなったと判断してよいだろうか．
# $$
# H_0 \colon p = 0.5 \\
# H_1 \colon p > 0.5
# $$
# として，有意水準$5\%$で片側検定したい．
# どのような計算を行えばよいか，下のセルにコードを書け．
#
# また，検定結果を下のセルに記述せよ．

# %%
# ここにコードを書く
result = 1 - stats.binom.cdf(14-1,20,0.5)
result.item()
# Out:
# 0.057659149169921875

# %% [markdown]
# #### 検定結果
#
# （ここに検定の結果を書き込む）
#
# コインを$20$回投げて$14$回以上表が出る確率は，$0.058$であり，片側有意水準の$0.05$より大きい．
#
# ゆえに，有意水準$5\%$の片側検定により，帰無仮説$H_0$は棄却されない．

# %% [markdown]
# # t分布とt検定
#
# ## 問題-2
#
# 標準正規分布$N(0,1)$の確率密度関数のグラフと，次のt分布の確率密度関数のグラフを，区間$[-3,3]$においてそれぞれ重ねて表示せよ．
#
# また，自由度$n$を変化させることで，$N(0,1)$と$t_n$の確率密度関数のグラフの間に見られる関係について考察せよ．
#
# ##### ヒント
#
# 自由度$n$のt分布の確率密度関数のグラフの描画には，次が使える．
# ```
# # dfが自由度
# stat.t.pdf(x,df=n)
# ```
#
# なお，標準正規分布の確率密度関数のグラフの描画は，次のコードを利用してよい．

# %%
x = np.arange(-3,3,0.01)

# 正規分布の確率密度関数を，緑色，破線で描画する
plt.plot(x,stats.norm.pdf(x,loc=0,scale=1), "--", color="green", label="Normal")
plt.title("Normal Distribution")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 1. $t_2$

# %%
x = np.arange(-3,3,0.01)

plt.plot(x,stats.norm.pdf(x,loc=0,scale=1), "--", color="green", label="Normal")
plt.plot(x,stats.t.pdf(x,df=2), color="orange", label="T2")
plt.title("Normal Distribution v.s. t2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 2. $t_{10}$

# %%
x = np.arange(-3,3,0.01)

plt.plot(x,stats.norm.pdf(x,loc=0,scale=1), "--", color="green", label="Normal")
plt.plot(x,stats.t.pdf(x,df=10), color="orange", label="T10")
plt.title("Normal Distribution v.s. t10")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 3. $t_{30}$

# %%
x = np.arange(-3,3,0.01)

plt.plot(x,stats.norm.pdf(x,loc=0,scale=1), "--", color="green", label="Normal")
plt.plot(x,stats.t.pdf(x,df=30), color="orange", label="T30")
plt.title("Normal Distribution v.s. t30")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 4. $t_{100}$

# %%
x = np.arange(-3,3,0.01)

plt.plot(x,stats.norm.pdf(x,loc=0,scale=1), "--", color="green", label="Normal")
plt.plot(x,stats.t.pdf(x,df=100), color="orange", label="T100")
plt.title("Normal Distribution v.s. t100")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### 考察
#
# 自由度$n$が大きくなるほど，t分布と標準正規分布の確率密度関数のグラフは近寄って見える．

# %% [markdown]
# ## 例題2-問題3
#
# ある機械で生産された$10$個の製品の重量を測定したところ
# $$
# 101.1, 103.2. 102.1, 99.2, 100.5, 101.3, 99.7, 100.5, 98.9, 101.4 \quad [\text{g}]
# $$
# のような結果を得た．
#
# 測定結果については，次のコードから取得せよ．

# %%
data = [101.1, 103.2, 102.1, 99.2, 100.5, 101.3, 99.7, 100.5, 98.9, 101.4]
series = pd.Series(data)

# %% [markdown]
# 0. （仮説の設定）母平均は$100\text{g}$と考えてよいだろうか．
# この検証のために，仮説検定を行いたい．
# 帰無仮説$H_0$と対立仮説は何であるべきか．
# 下のセルに書き込め．

# %% [markdown]
# 帰無仮説$H_0$: $\mu = 100$
#
# 対立仮説$H_1$: $\mu \neq 100$

# %% [markdown]
# 1. （直接立式して計算）母平均は$100\text{g}$と考えてよいだろうか．
# 次の手順で計算を行うことにより，有意水準$5\%$で検定せよ．
# 必要ならば，コード記述欄の下の**ヒント**も参考にせよ．
#
#     1. `series`に含まれるデータの平均と不偏標本分散の正の平方根を，それぞれ変数`m`，`s`に入れる．
#     1. `u`にt分布の上位$2.5\\%$点の値を入れる．
#     1. t統計量`t`を計算する．
#     1. `t>=0`ならば，`t`と`u`の値を比較する．（帰無仮説$H_0$が棄却できないときに，ブール値`True`を吐くようにするにはどうすればよいだろうか．）`t<0`ならば，`-t`と`u`の値を比較する．帰無仮説$H_0$が棄却される場合は`False`，棄却されない場合は`True`を表示するようにせよ．

# %%
m = np.mean(series)
s = np.std(series, ddof=1)
t = (m - 100)/(s/np.sqrt(10))
u = stats.t.ppf(0.975,df=9)
print("t統計量: {:.3f}，上位2.5%点: {:.3f}".format(t,u))
if t >= 0:
    print(t < u)
else:
    print(-t < u)
# Out:
# t統計量: 1.891，上位2.5%点: 2.262
# True

# %% [markdown]
# ##### ヒント
#
# * `Series`オブジェクトに対しては，`numpy`モジュールの関数`np.mean(Series)`，`np.var(Series,ddof=1)`でそれぞれ標本平均，不偏標本分散が計算できる．`np.var()`の`ddof`の値を`0`にすると，不偏でない標本分散（データを母集団とみなした分散），`1`にすると，不偏標本分散（データを母集団から抽出した標本とみなした分散）が計算される．
#
# * 数値に対して，その平方根を計算するには，`numpy`モジュールの関数`np.sqrt()`が利用できる．
# なお，`np.sqrt(np.var())`は，標準偏差を与える関数`np.std()`と同等である．関数`np.std()`においても`ddof`の値を設定できる．
#
# * 自由度`n`のt分布の上位$100\alpha\%$点を与える関数は，`scipy.stats`で提供されている
# ```
# stats.t.ppf(1-a,df=n)
# ```
# が利用できる．
#     * （補足）`1-a`の理由: 統計学の教科書では，通常$100\alpha\%$点というと上から$100\alpha\%$の$x$座標を表すのであるが，pythonでは下から$100\alpha\%$の$x$座標を表す流儀（つまり累積分布関数の逆関数）のようである．
#
# * 不等式や等式は，ブール値（「真（`True`）」「偽（`False`）」の$2$値）として扱われる．
# ```
# 2 < 3 # 実行すると「True」が表示される．以下同様
# 2 > 3 # False
# 2 == 3 # False
# 2 != 3 # True
# ```
#
#     * （補足）ブール値は，`and`，`or`，`not`を演算子にもつブール代数をなす．
#     ```
#     True and False # False
#     True or False # True
#     not True # False
#     ```

# %% [markdown]
# 2. （関数利用）母平均は$100\text{g}$と考えてよいだろうか．
# 次の手順で計算を行うことにより，有意水準$5\%$で検定せよ．
#
#     1. `stats.ttest_1samp(Data, Popmean)`で標本`Data`と帰無仮説で仮定する母平均`Popmean`から，自動的に取得された自由度によるt分布の検定統計量`t`と$p$値`p`（検定統計量`t`の，分布の上位または下位からの割合の小さいほう）が得られる．構文は
# ```
# t, p = stats.ttest_1samp(Data, Popmean)
# ```
# である．
#
#     2. 求めるべきは，この$p$値`p`が有意水準の半分である$0.025$より小さいか否かである．$p>0.025$であるとき，`t`統計量の値はそれほど稀な事象ではないということであり，帰無仮説$H_0$は棄却されない．$p<0.025$のとき，帰無仮説$H_0$は棄却される．よって，`p>0.025`となるときに`True`が吐き出されるようにすればよい．

# %%
t, p = stats.ttest_1samp(series,100)
print("t統計量: {:.3f}，p値: {:.3f}".format(t,p))
print(p > 0.025)
# Out:
# t統計量: 1.891，p値: 0.091
# True

# %% [markdown]
# 3. （復習，直接立式して計算）上の測定結果をもとに，製品の重量の母平均の信頼度$95\%$信頼区間を求めよ．
# また，上の検定結果と比較し，それぞれの意味について考察せよ．
#
# なお，自由度$n$のt分布の$2.5\%$点を$t_{n,0.025}$と表すと，信頼度$95\%$の信頼区間における上側信頼限界，下側信頼限界はそれぞれ
# $$
# \overline{x} \pm t_{n, 0.025} \cdot \frac{\hat{s}}{\sqrt{n}}
# $$

# %%
d = stats.t.ppf(0.975,df=9)*s/np.sqrt(10)
print("95%信頼区間は，[{:.3f},{:.3f}]で与えられる".format(m-d,m+d))
# Out:
# 95%信頼区間は，[99.845,101.735]で与えられる

# %% [markdown]
# 4. （関数利用）上の測定結果をもとに，次の手順に従い，製品の重量の母平均の信頼度$95\%$信頼区間を求めよ．
#
#     1. 不偏分散を$\hat{S}^2$とすると，大きさ$n$の標本の**標準誤差**（標本平均の標準偏差）は$\hat{S}/\sqrt{n}$と書ける．
# この標準誤差を`seq`に格納すると，母平均の信頼度$100\alpha\%$信頼区間は，
# ```
# # m: 標本平均，n-1: 自由度，100*a: 信頼度
# stats.t.interval(alpha=a, df=n-1, loc=m, scale=sep)
# ```
# で計算される．

# %%
sep = s / np.sqrt(10)
low, high = stats.t.interval(confidence=0.95, df=9, loc=m, scale=sep)
print(f"信頼区間: ({float(low):.3f}, {float(high):.3f})")
# Out:
# 信頼区間: (99.845, 101.735)

# %%
# いつものモジュールのインポート
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # 検出力
#
# A商店では，新製品のクッキー（A）の市場での評価を試験するために，試食会において従来品のクッキー（B)と比較して，どちらをより好むかについてのアンケートをとった．その結果が次の通りである．
#
# | | A | B | 計 |
# | ---- | ---- | ---- | ---- |
# | どちらを好むか | 10 | 5 | 15 |
#
# 1. アンケートをとった人数（標本の大きさ）を$N$，Aのクッキーを好むとした人の割合を$p_{\text{sample}}$とする．\
# まず，$N$（`N`），$p_{\text{sample}}$（`p_sample`）に，アンケートの結果から分かる適切な数値を入力せよ．\
# 次に，この標本から無作為に1人を抽出したとき，その1人の回答の仕方は二項分布$B(1,p_{\text{sample}})$に従うとみなせる．この分布の分散$v$を`v`に入力せよ．
#
# この計算結果（$p_{\text{sample}}$，$v$）は，母集団（顧客全体）から無作為に1人を抽出したとき，Aを選択する確率$p$に関する推定量の分布を与える．

# %%
N = 15
p_sample = 10 / 15
v = p_sample * (1-p_sample)

# %% [markdown]
# 2. この結果から，新製品のクッキーがより好まれると結論付けてよいだろうか．
# 母集団におけるAを選択する確率$p$について，
# $$
# H_0 \colon p = 0.5, \quad H_1 \colon p > 0.5
# $$
# とし，有意水準$5\%$の右片側検定により，判断せよ．
# ただし，母集団の分散は標本分散$v$に等しく既知であるとし，二項分布の正規分布への近似を利用し，z検定を行うこと．
# また，検定の根拠となる`p_sample`及び`ppt`の値も明示すること．\
# ヒント:
#   1. 帰無仮説$H_0 \colon p = 0.5$に基づく，（右片側検定であるから）上位$5\%$点を`ppt`に格納するには，次の書式を利用する．
#   ```
#   ppt = stats.norm.ppf(0.95,loc=0.5,scale=標準偏差)
#   ```
#   （`stats.norm.ppf(x,loc=平均,scale=標準偏差)`は，正規分布で下から数えてxとなる$x$座標を与える．つまり累積分布関数の逆関数である）．\
#   ここで，今回は標本数が`N`の標本調査を行っているため，標準偏差の計算にあたり，上で定義した`v`を直接利用するのではないことに注意されたい．また，平方根の計算には，`np.sqrt()`関数を利用せよ．

# %%
percent = 0.95

ppt = stats.norm.ppf(0.95,loc=0.5,scale=np.sqrt(v/N))

print("p_sample={:.4f}，上位5%点はppt={:.4f}である．".format(p_sample,ppt))
if p_sample < ppt:
  print("p_sample<pptであるため，H_0は棄却されず，クッキーAがより好まれるとは言えない．")
else:
  print("p_sample>pptであるため，H_0は棄却され，クッキーAがより好まれると言える．")
# Out:
# p_sample=0.6667，上位5%点はppt=0.7002である．
# p_sample<pptであるため，H_0は棄却されず，クッキーAがより好まれるとは言えない．

# %% [markdown]
# 3. この検定の検出力を求めよ．
# 効果量は$\Delta = 0.1$とする．\
# 手順:
#   1. 効果量`Delta`に，$0.1$を入力する．
#   2. $H_1 \colon p = 0.5 + \Delta$のもとで，第2種の誤りを犯す確率$\beta$を求める．
#   $H_1$が採択されるべきにも関わらず$H_0$が棄却できない確率が$\beta$であるから，$H_1$に基づく分布の下で，（右片側検定を行っているので）大きさ`N`の標本から求めた$p$の標本平均が上で求めた`ppt`を下回る確率を求めればよい．
#   このためには，
#   ```
#   beta = stats.norm.cdf(ppt,loc=効果量を加味した母平均,scale=標準偏差)
#   ```
#   とすればよい（`stats.norm.cdf(x)`は`x`までの累積分布関数の値，`x`以下の確率の総和である）．
#   3. 検出力は，効果量$\Delta$に基づく$1-\beta$で計算される．
#   `1-beta`を出力せよ:
#   ```
#   print("Delta={}としたときのこの検定の検出力は，{:.4f}である．".format(Delta,1-beta))
#   ```

# %%
Delta = 0.1
beta = stats.norm.cdf(ppt,loc=0.5+Delta,scale=np.sqrt(v/N))

print("Delta={}としたときのこの検定の検出力は，{:.4f}である．".format(Delta,1-beta))
# Out:
# Delta=0.1としたときのこの検定の検出力は，0.2052である．

# %% [markdown]
# 4. この検定の検出力を$80\%$（$0.80$）としたいとき，次の考えに従って，適切な標本数（アンケート実施人数）$n$を求める式を入力し，計算結果を出力せよ．
#
#   1. 帰無仮説$H_0 \colon p = 0.5$に基づいて$p = 0.5$とした母集団の分布における，上側$5\%$点$x_{\text{ppt}}$を与える式は
#   $$
#   x_{\text{ppt}} = 0.5 + z(0.05) \cdot \sqrt{ \frac{p(1-p)}{n} }  \quad (\text{$z(0.05)$は標準正規分布における上側$5\%$点を与える座標})
#   $$
#   である．
#   今回は，問題の設定上，先に得られた標本分散を母分散として用いるため，上式の根号の中では$p = p_{\text{sample}}$として計算する．
#   2. 効果量を$\Delta=0.1$とすると，$H_1 \colon p = 0.5 + \Delta$に基づく母集団の分布における，（右片側検定であるから）下側$20\%$点を与える式は
#   $$
#   x_{\text{beta_bound}} = 0.5 + \Delta - z(0.20) \cdot \sqrt{ \frac{p(1-p)}{n} }
#   $$
#   で与えられる．この式においても，根号の中では$p = p_{\text{sample}}$の値を用いる．
#   3. $x_{\text{ppt}} = x_{\text{beta_bound}}$として，$n$に関する方程式とみなして，$n$について解く．
#   実数解$n$に最も近い整数値（`round(n)`）が，今回求めるべき標本数である．
#
#   ヒント:
#   標準正規分布における上側$100\alpha\%$点$z(\alpha)$を求めるコードは（平均`0`，標準偏差`1`とすればよいから）
#   ```
#   stats.norm.ppt(1-0.05,loc=0,scale=1)
#   ```
#   を利用せよ．
#
#   ![116_power.png](data:image/png;base64,...)

# %%
ppt_0 = stats.norm.ppf(0.95,loc=0,scale=1) # H_0の下での標準正規分布の上側5%点
ppt_1 = stats.norm.ppf(0.80,loc=0,scale=1) #H_1の下での標準正規分布の上側20%点
n = ( (ppt_0 + ppt_1) / Delta )**2 * p_sample * (1 - p_sample)
print("検出力が0.80に一番近くなる標本の大きさは，n={}である．".format(round(n)))
# Out:
# 検出力が0.80に一番近くなる標本の大きさは，n=137である．

# %% [markdown]
# 最後に，答え合わせのために，次のコードを実行してみよ（正しい`v`が，上のセルで入力されている必要がある）．

# %%
for n in range(1,1000):
  beta = stats.norm.cdf(stats.norm.ppf(0.95,loc=0.5,scale=np.sqrt(v/n)),loc=0.5+Delta,scale=np.sqrt(v/n))
  print("n={}のとき，検出力は{:.4f}である．".format(n,1 - beta))
# Out:
# n=1のとき，検出力は0.0760である．
# n=2のとき，検出力は0.0893である．
# n=3のとき，検出力は0.1007である．
# n=4のとき，検出力は0.1111である．
# n=5のとき，検出力は0.1209である．
# n=6のとき，検出力は0.1302である．
# n=7のとき，検出力は0.1393である．
# n=8のとき，検出力は0.1480である．
# n=9のとき，検出力は0.1566である．
# n=10のとき，検出力は0.1650である．
# n=11のとき，検出力は0.1733である．
# n=12のとき，検出力は0.1814である．
# n=13のとき，検出力は0.1894である．
# n=14のとき，検出力は0.1973である．
# n=15のとき，検出力は0.2052である．
# n=16のとき，検出力は0.2129である．
# n=17のとき，検出力は0.2206である．
# n=18のとき，検出力は0.2282である．
# n=19のとき，検出力は0.2357である．
# n=20のとき，検出力は0.2432である．
# n=21のとき，検出力は0.2506である．
# n=22のとき，検出力は0.2579である．
# n=23のとき，検出力は0.2652である．
# n=24のとき，検出力は0.2724である．
# n=25のとき，検出力は0.2795である．
# n=26のとき，検出力は0.2867である．
# n=27のとき，検出力は0.2937である．
# n=28のとき，検出力は0.3007である．
# n=29のとき，検出力は0.3077である．
# n=30のとき，検出力は0.3146である．
# n=31のとき，検出力は0.3214である．
# n=32のとき，検出力は0.3282である．
# n=33のとき，検出力は0.3350である．
# n=34のとき，検出力は0.3417である．
# n=35のとき，検出力は0.3483である．
# n=36のとき，検出力は0.3549である．
# n=37のとき，検出力は0.3615である．
# n=38のとき，検出力は0.3680である．
# n=39のとき，検出力は0.3745である．
# n=40のとき，検出力は0.3809である．
# n=41のとき，検出力は0.3872である．
# n=42のとき，検出力は0.3935である．
# n=43のとき，検出力は0.3998である．
# n=44のとき，検出力は0.4060である．
# n=45のとき，検出力は0.4122である．
# n=46のとき，検出力は0.4184である．
# n=47のとき，検出力は0.4244である．
# n=48のとき，検出力は0.4305である．
# n=49のとき，検出力は0.4365である．
# n=50のとき，検出力は0.4424である．
# n=51のとき，検出力は0.4483である．
# n=52のとき，検出力は0.4542である．
# n=53のとき，検出力は0.4600である．
# n=54のとき，検出力は0.4657である．
# n=55のとき，検出力は0.4714である．
# n=56のとき，検出力は0.4771である．
# n=57のとき，検出力は0.4827である．
# n=58のとき，検出力は0.4883である．
# n=59のとき，検出力は0.4938である．
# n=60のとき，検出力は0.4993である．
# n=61のとき，検出力は0.5048である．
# n=62のとき，検出力は0.5102である．
# n=63のとき，検出力は0.5155である．
# n=64のとき，検出力は0.5208である．
# n=65のとき，検出力は0.5261である．
# n=66のとき，検出力は0.5313である．
# n=67のとき，検出力は0.5365である．
# n=68のとき，検出力は0.5416である．
# n=69のとき，検出力は0.5467である．
# n=70のとき，検出力は0.5517である．
# n=71のとき，検出力は0.5567である．
# n=72のとき，検出力は0.5616である．
# n=73のとき，検出力は0.5666である．
# n=74のとき，検出力は0.5714である．
# n=75のとき，検出力は0.5762である．
# n=76のとき，検出力は0.5810である．
# n=77のとき，検出力は0.5857である．
# n=78のとき，検出力は0.5904である．
# n=79のとき，検出力は0.5951である．
# n=80のとき，検出力は0.5997である．
# n=81のとき，検出力は0.6042である．
# n=82のとき，検出力は0.6088である．
# n=83のとき，検出力は0.6132である．
# n=84のとき，検出力は0.6177である．
# n=85のとき，検出力は0.6221である．
# n=86のとき，検出力は0.6264である．
# n=87のとき，検出力は0.6307である．
# n=88のとき，検出力は0.6350である．
# n=89のとき，検出力は0.6392である．
# n=90のとき，検出力は0.6434である．
# n=91のとき，検出力は0.6476である．
# n=92のとき，検出力は0.6517である．
# n=93のとき，検出力は0.6557である．
# n=94のとき，検出力は0.6598である．
# n=95のとき，検出力は0.6638である．
# n=96のとき，検出力は0.6677である．
# n=97のとき，検出力は0.6716である．
# n=98のとき，検出力は0.6755である．
# n=99のとき，検出力は0.6793である．
# n=100のとき，検出力は0.6831である．
# n=101のとき，検出力は0.6869である．
# n=102のとき，検出力は0.6906である．
# n=103のとき，検出力は0.6943である．
# n=104のとき，検出力は0.6979である．
# n=105のとき，検出力は0.7015である．
# n=106のとき，検出力は0.7051である．
# n=107のとき，検出力は0.7087である．
# n=108のとき，検出力は0.7122である．
# n=109のとき，検出力は0.7156である．
# n=110のとき，検出力は0.7190である．
# n=111のとき，検出力は0.7224である．
# n=112のとき，検出力は0.7258である．
# n=113のとき，検出力は0.7291である．
# n=114のとき，検出力は0.7324である．
# n=115のとき，検出力は0.7357である．
# n=116のとき，検出力は0.7389である．
# n=117のとき，検出力は0.7421である．
# n=118のとき，検出力は0.7452である．
# n=119のとき，検出力は0.7483である．
# n=120のとき，検出力は0.7514である．
# n=121のとき，検出力は0.7545である．
# n=122のとき，検出力は0.7575である．
# n=123のとき，検出力は0.7605である．
# n=124のとき，検出力は0.7634である．
# n=125のとき，検出力は0.7663である．
# n=126のとき，検出力は0.7692である．
# n=127のとき，検出力は0.7721である．
# n=128のとき，検出力は0.7749である．
# n=129のとき，検出力は0.7777である．
# n=130のとき，検出力は0.7805である．
# n=131のとき，検出力は0.7832である．
# n=132のとき，検出力は0.7859である．
# n=133のとき，検出力は0.7886である．
# n=134のとき，検出力は0.7912である．
# n=135のとき，検出力は0.7939である．
# n=136のとき，検出力は0.7965である．
# n=137のとき，検出力は0.7990である．
# n=138のとき，検出力は0.8015である．
# n=139のとき，検出力は0.8040である．
# n=140のとき，検出力は0.8065である．
# n=141のとき，検出力は0.8090である．
# n=142のとき，検出力は0.8114である．
# n=143のとき，検出力は0.8138である．
# n=144のとき，検出力は0.8161である．
# n=145のとき，検出力は0.8185である．
# n=146のとき，検出力は0.8208である．
# n=147のとき，検出力は0.8231である．
# n=148のとき，検出力は0.8253である．
# n=149のとき，検出力は0.8276である．
# n=150のとき，検出力は0.8298である．
# n=151のとき，検出力は0.8319である．
# n=152のとき，検出力は0.8341である．
# n=153のとき，検出力は0.8362である．
# n=154のとき，検出力は0.8383である．
# n=155のとき，検出力は0.8404である．
# n=156のとき，検出力は0.8425である．
# n=157のとき，検出力は0.8445である．
# n=158のとき，検出力は0.8465である．
# n=159のとき，検出力は0.8485である．
# n=160のとき，検出力は0.8505である．
# n=161のとき，検出力は0.8524である．
# n=162のとき，検出力は0.8543である．
# n=163のとき，検出力は0.8562である．
# n=164のとき，検出力は0.8581である．
# n=165のとき，検出力は0.8599である．
# n=166のとき，検出力は0.8618である．
# n=167のとき，検出力は0.8636である．
# n=168のとき，検出力は0.8654である．
# n=169のとき，検出力は0.8671である．
# n=170のとき，検出力は0.8689である．
# n=171のとき，検出力は0.8706である．
# n=172のとき，検出力は0.8723である．
# n=173のとき，検出力は0.8740である．
# n=174のとき，検出力は0.8756である．
# n=175のとき，検出力は0.8773である．
# n=176のとき，検出力は0.8789である．
# n=177のとき，検出力は0.8805である．
# n=178のとき，検出力は0.8821である．
# n=179のとき，検出力は0.8836である．
# n=180のとき，検出力は0.8852である．
# n=181のとき，検出力は0.8867である．
# n=182のとき，検出力は0.8882である．
# n=183のとき，検出力は0.8897である．
# n=184のとき，検出力は0.8911である．
# n=185のとき，検出力は0.8926である．
# n=186のとき，検出力は0.8940である．
# n=187のとき，検出力は0.8954である．
# n=188のとき，検出力は0.8968である．
# n=189のとき，検出力は0.8982である．
# n=190のとき，検出力は0.8996である．
# n=191のとき，検出力は0.9009である．
# n=192のとき，検出力は0.9023である．
# n=193のとき，検出力は0.9036である．
# n=194のとき，検出力は0.9049である．
# n=195のとき，検出力は0.9061である．
# n=196のとき，検出力は0.9074である．
# n=197のとき，検出力は0.9087である．
# n=198のとき，検出力は0.9099である．
# n=199のとき，検出力は0.9111である．
# n=200のとき，検出力は0.9123である．
# n=201のとき，検出力は0.9135である．
# n=202のとき，検出力は0.9147である．
# n=203のとき，検出力は0.9158である．
# n=204のとき，検出力は0.9170である．
# n=205のとき，検出力は0.9181である．
# n=206のとき，検出力は0.9192である．
# n=207のとき，検出力は0.9203である．
# n=208のとき，検出力は0.9214である．
# n=209のとき，検出力は0.9225である．
# n=210のとき，検出力は0.9235である．
# n=211のとき，検出力は0.9246である．
# n=212のとき，検出力は0.9256である．
# n=213のとき，検出力は0.9266である．
# n=214のとき，検出力は0.9276である．
# n=215のとき，検出力は0.9286である．
# n=216のとき，検出力は0.9296である．
# n=217のとき，検出力は0.9306である．
# n=218のとき，検出力は0.9315である．
# n=219のとき，検出力は0.9325である．
# n=220のとき，検出力は0.9334である．
# n=221のとき，検出力は0.9343である．
# n=222のとき，検出力は0.9352である．
# n=223のとき，検出力は0.9361である．
# n=224のとき，検出力は0.9370である．
# n=225のとき，検出力は0.9379である．
# n=226のとき，検出力は0.9387である．
# n=227のとき，検出力は0.9396である．
# n=228のとき，検出力は0.9404である．
# n=229のとき，検出力は0.9412である．
# n=230のとき，検出力は0.9421である．
# n=231のとき，検出力は0.9429である．
# n=232のとき，検出力は0.9437である．
# n=233のとき，検出力は0.9444である．
# n=234のとき，検出力は0.9452である．
# n=235のとき，検出力は0.9460である．
# n=236のとき，検出力は0.9467である．
# n=237のとき，検出力は0.9475である．
# n=238のとき，検出力は0.9482である．
# n=239のとき，検出力は0.9489である．
# n=240のとき，検出力は0.9497である．
# n=241のとき，検出力は0.9504である．
# n=242のとき，検出力は0.9511である．
# n=243のとき，検出力は0.9517である．
# n=244のとき，検出力は0.9524である．
# n=245のとき，検出力は0.9531である．
# n=246のとき，検出力は0.9537である．
# n=247のとき，検出力は0.9544である．
# n=248のとき，検出力は0.9550である．
# n=249のとき，検出力は0.9557である．
# n=250のとき，検出力は0.9563である．
# n=251のとき，検出力は0.9569である．
# n=252のとき，検出力は0.9575である．
# n=253のとき，検出力は0.9581である．
# n=254のとき，検出力は0.9587である．
# n=255のとき，検出力は0.9593である．
# n=256のとき，検出力は0.9599である．
# n=257のとき，検出力は0.9604である．
# n=258のとき，検出力は0.9610である．
# n=259のとき，検出力は0.9616である．
# n=260のとき，検出力は0.9621である．
# n=261のとき，検出力は0.9626である．
# n=262のとき，検出力は0.9632である．
# n=263のとき，検出力は0.9637である．
# n=264のとき，検出力は0.9642である．
# n=265のとき，検出力は0.9647である．
# n=266のとき，検出力は0.9652である．
# n=267のとき，検出力は0.9657である．
# n=268のとき，検出力は0.9662である．
# n=269のとき，検出力は0.9667である．
# n=270のとき，検出力は0.9672である．
# n=271のとき，検出力は0.9676である．
# n=272のとき，検出力は0.9681である．
# n=273のとき，検出力は0.9686である．
# n=274のとき，検出力は0.9690である．
# n=275のとき，検出力は0.9695である．
# n=276のとき，検出力は0.9699である．
# n=277のとき，検出力は0.9703である．
# n=278のとき，検出力は0.9708である．
# n=279のとき，検出力は0.9712である．
# n=280のとき，検出力は0.9716である．
# n=281のとき，検出力は0.9720である．
# n=282のとき，検出力は0.9724である．
# n=283のとき，検出力は0.9728である．
# n=284のとき，検出力は0.9732である．
# n=285のとき，検出力は0.9736である．
# n=286のとき，検出力は0.9740である．
# n=287のとき，検出力は0.9743である．
# n=288のとき，検出力は0.9747である．
# n=289のとき，検出力は0.9751である．
# n=290のとき，検出力は0.9754である．
# n=291のとき，検出力は0.9758である．
# n=292のとき，検出力は0.9762である．
# n=293のとき，検出力は0.9765である．
# n=294のとき，検出力は0.9768である．
# n=295のとき，検出力は0.9772である．
# n=296のとき，検出力は0.9775である．
# n=297のとき，検出力は0.9778である．
# n=298のとき，検出力は0.9782である．
# n=299のとき，検出力は0.9785である．
# n=300のとき，検出力は0.9788である．
# n=301のとき，検出力は0.9791である．
# n=302のとき，検出力は0.9794である．
# n=303のとき，検出力は0.9797である．
# n=304のとき，検出力は0.9800である．
# n=305のとき，検出力は0.9803である．
# n=306のとき，検出力は0.9806である．
# n=307のとき，検出力は0.9809である．
# n=308のとき，検出力は0.9811である．
# n=309のとき，検出力は0.9814である．
# n=310のとき，検出力は0.9817である．
# n=311のとき，検出力は0.9820である．
# n=312のとき，検出力は0.9822である．
# n=313のとき，検出力は0.9825である．
# n=314のとき，検出力は0.9827である．
# n=315のとき，検出力は0.9830である．
# n=316のとき，検出力は0.9833である．
# n=317のとき，検出力は0.9835である．
# n=318のとき，検出力は0.9837である．
# n=319のとき，検出力は0.9840である．
# n=320のとき，検出力は0.9842である．
# n=321のとき，検出力は0.9845である．
# n=322のとき，検出力は0.9847である．
# n=323のとき，検出力は0.9849である．
# n=324のとき，検出力は0.9851である．
# n=325のとき，検出力は0.9853である．
# n=326のとき，検出力は0.9856である．
# n=327のとき，検出力は0.9858である．
# n=328のとき，検出力は0.9860である．
# n=329のとき，検出力は0.9862である．
# n=330のとき，検出力は0.9864である．
# n=331のとき，検出力は0.9866である．
# n=332のとき，検出力は0.9868である．
# n=333のとき，検出力は0.9870である．
# n=334のとき，検出力は0.9872である．
# n=335のとき，検出力は0.9874である．
# n=336のとき，検出力は0.9876である．
# n=337のとき，検出力は0.9878である．
# n=338のとき，検出力は0.9879である．
# n=339のとき，検出力は0.9881である．
# n=340のとき，検出力は0.9883である．
# n=341のとき，検出力は0.9885である．
# n=342のとき，検出力は0.9886である．
# n=343のとき，検出力は0.9888である．
# n=344のとき，検出力は0.9890である．
# n=345のとき，検出力は0.9891である．
# n=346のとき，検出力は0.9893である．
# n=347のとき，検出力は0.9895である．
# n=348のとき，検出力は0.9896である．
# n=349のとき，検出力は0.9898である．
# n=350のとき，検出力は0.9899である．
# n=351のとき，検出力は0.9901である．
# n=352のとき，検出力は0.9902である．
# n=353のとき，検出力は0.9904である．
# n=354のとき，検出力は0.9905である．
# n=355のとき，検出力は0.9907である．
# n=356のとき，検出力は0.9908である．
# n=357のとき，検出力は0.9909である．
# n=358のとき，検出力は0.9911である．
# n=359のとき，検出力は0.9912である．
# n=360のとき，検出力は0.9913である．
# n=361のとき，検出力は0.9915である．
# n=362のとき，検出力は0.9916である．
# n=363のとき，検出力は0.9917である．
# n=364のとき，検出力は0.9919である．
# n=365のとき，検出力は0.9920である．
# n=366のとき，検出力は0.9921である．
# n=367のとき，検出力は0.9922である．
# n=368のとき，検出力は0.9923である．
# n=369のとき，検出力は0.9925である．
# n=370のとき，検出力は0.9926である．
# n=371のとき，検出力は0.9927である．
# n=372のとき，検出力は0.9928である．
# n=373のとき，検出力は0.9929である．
# n=374のとき，検出力は0.9930である．
# n=375のとき，検出力は0.9931である．
# n=376のとき，検出力は0.9932である．
# n=377のとき，検出力は0.9933である．
# n=378のとき，検出力は0.9934である．
# n=379のとき，検出力は0.9935である．
# n=380のとき，検出力は0.9936である．
# n=381のとき，検出力は0.9937である．
# n=382のとき，検出力は0.9938である．
# n=383のとき，検出力は0.9939である．
# n=384のとき，検出力は0.9940である．
# n=385のとき，検出力は0.9941である．
# n=386のとき，検出力は0.9942である．
# n=387のとき，検出力は0.9943である．
# n=388のとき，検出力は0.9944である．
# n=389のとき，検出力は0.9944である．
# n=390のとき，検出力は0.9945である．
# n=391のとき，検出力は0.9946である．
# n=392のとき，検出力は0.9947である．
# n=393のとき，検出力は0.9948である．
# n=394のとき，検出力は0.9949である．
# n=395のとき，検出力は0.9949である．
# n=396のとき，検出力は0.9950である．
# n=397のとき，検出力は0.9951である．
# n=398のとき，検出力は0.9952である．
# n=399のとき，検出力は0.9952である．
# n=400のとき，検出力は0.9953である．
# n=401のとき，検出力は0.9954である．
# n=402のとき，検出力は0.9955である．
# n=403のとき，検出力は0.9955である．
# n=404のとき，検出力は0.9956である．
# n=405のとき，検出力は0.9957である．
# n=406のとき，検出力は0.9957である．
# n=407のとき，検出力は0.9958である．
# n=408のとき，検出力は0.9959である．
# n=409のとき，検出力は0.9959である．
# n=410のとき，検出力は0.9960である．
# n=411のとき，検出力は0.9960である．
# n=412のとき，検出力は0.9961である．
# n=413のとき，検出力は0.9962である．
# n=414のとき，検出力は0.9962である．
# n=415のとき，検出力は0.9963である．
# n=416のとき，検出力は0.9963である．
# n=417のとき，検出力は0.9964である．
# n=418のとき，検出力は0.9965である．
# n=419のとき，検出力は0.9965である．
# n=420のとき，検出力は0.9966である．
# n=421のとき，検出力は0.9966である．
# n=422のとき，検出力は0.9967である．
# n=423のとき，検出力は0.9967である．
# n=424のとき，検出力は0.9968である．
# n=425のとき，検出力は0.9968である．
# n=426のとき，検出力は0.9969である．
# n=427のとき，検出力は0.9969である．
# n=428のとき，検出力は0.9970である．
# n=429のとき，検出力は0.9970である．
# n=430のとき，検出力は0.9971である．
# n=431のとき，検出力は0.9971である．
# n=432のとき，検出力は0.9971である．
# n=433のとき，検出力は0.9972である．
# n=434のとき，検出力は0.9972である．
# n=435のとき，検出力は0.9973である．
# n=436のとき，検出力は0.9973である．
# n=437のとき，検出力は0.9974である．
# n=438のとき，検出力は0.9974である．
# n=439のとき，検出力は0.9974である．
# n=440のとき，検出力は0.9975である．
# n=441のとき，検出力は0.9975である．
# n=442のとき，検出力は0.9976である．
# n=443のとき，検出力は0.9976である．
# n=444のとき，検出力は0.9976である．
# n=445のとき，検出力は0.9977である．
# n=446のとき，検出力は0.9977である．
# n=447のとき，検出力は0.9977である．
# n=448のとき，検出力は0.9978である．
# n=449のとき，検出力は0.9978である．
# n=450のとき，検出力は0.9978である．
# n=451のとき，検出力は0.9979である．
# n=452のとき，検出力は0.9979である．
# n=453のとき，検出力は0.9979である．
# n=454のとき，検出力は0.9980である．
# n=455のとき，検出力は0.9980である．
# n=456のとき，検出力は0.9980である．
# n=457のとき，検出力は0.9981である．
# n=458のとき，検出力は0.9981である．
# n=459のとき，検出力は0.9981である．
# n=460のとき，検出力は0.9982である．
# n=461のとき，検出力は0.9982である．
# n=462のとき，検出力は0.9982である．
# n=463のとき，検出力は0.9982である．
# n=464のとき，検出力は0.9983である．
# n=465のとき，検出力は0.9983である．
# n=466のとき，検出力は0.9983である．
# n=467のとき，検出力は0.9984である．
# n=468のとき，検出力は0.9984である．
# n=469のとき，検出力は0.9984である．
# n=470のとき，検出力は0.9984である．
# n=471のとき，検出力は0.9985である．
# n=472のとき，検出力は0.9985である．
# n=473のとき，検出力は0.9985である．
# n=474のとき，検出力は0.9985である．
# n=475のとき，検出力は0.9986である．
# n=476のとき，検出力は0.9986である．
# n=477のとき，検出力は0.9986である．
# n=478のとき，検出力は0.9986である．
# n=479のとき，検出力は0.9986である．
# n=480のとき，検出力は0.9987である．
# n=481のとき，検出力は0.9987である．
# n=482のとき，検出力は0.9987である．
# n=483のとき，検出力は0.9987である．
# n=484のとき，検出力は0.9987である．
# n=485のとき，検出力は0.9988である．
# n=486のとき，検出力は0.9988である．
# n=487のとき，検出力は0.9988である．
# n=488のとき，検出力は0.9988である．
# n=489のとき，検出力は0.9988である．
# n=490のとき，検出力は0.9989である．
# n=491のとき，検出力は0.9989である．
# n=492のとき，検出力は0.9989である．
# n=493のとき，検出力は0.9989である．
# n=494のとき，検出力は0.9989である．
# n=495のとき，検出力は0.9989である．
# n=496のとき，検出力は0.9990である．
# n=497のとき，検出力は0.9990である．
# n=498のとき，検出力は0.9990である．
# n=499のとき，検出力は0.9990である．
# n=500のとき，検出力は0.9990である．
# n=501のとき，検出力は0.9990である．
# n=502のとき，検出力は0.9991である．
# n=503のとき，検出力は0.9991である．
# n=504のとき，検出力は0.9991である．
# n=505のとき，検出力は0.9991である．
# n=506のとき，検出力は0.9991である．
# n=507のとき，検出力は0.9991である．
# n=508のとき，検出力は0.9991である．
# n=509のとき，検出力は0.9992である．
# n=510のとき，検出力は0.9992である．
# n=511のとき，検出力は0.9992である．
# n=512のとき，検出力は0.9992である．
# n=513のとき，検出力は0.9992である．
# n=514のとき，検出力は0.9992である．
# n=515のとき，検出力は0.9992である．
# n=516のとき，検出力は0.9992である．
# n=517のとき，検出力は0.9993である．
# n=518のとき，検出力は0.9993である．
# n=519のとき，検出力は0.9993である．
# n=520のとき，検出力は0.9993である．
# n=521のとき，検出力は0.9993である．
# n=522のとき，検出力は0.9993である．
# n=523のとき，検出力は0.9993である．
# n=524のとき，検出力は0.9993である．
# n=525のとき，検出力は0.9993である．
# n=526のとき，検出力は0.9994である．
# n=527のとき，検出力は0.9994である．
# n=528のとき，検出力は0.9994である．
# n=529のとき，検出力は0.9994である．
# n=530のとき，検出力は0.9994である．
# n=531のとき，検出力は0.9994である．
# n=532のとき，検出力は0.9994である．
# n=533のとき，検出力は0.9994である．
# n=534のとき，検出力は0.9994である．
# n=535のとき，検出力は0.9994である．
# n=536のとき，検出力は0.9995である．
# n=537のとき，検出力は0.9995である．
# n=538のとき，検出力は0.9995である．
# n=539のとき，検出力は0.9995である．
# n=540のとき，検出力は0.9995である．
# n=541のとき，検出力は0.9995である．
# n=542のとき，検出力は0.9995である．
# n=543のとき，検出力は0.9995である．
# n=544のとき，検出力は0.9995である．
# n=545のとき，検出力は0.9995である．
# n=546のとき，検出力は0.9995である．
# n=547のとき，検出力は0.9995である．
# n=548のとき，検出力は0.9996である．
# n=549のとき，検出力は0.9996である．
# n=550のとき，検出力は0.9996である．
# n=551のとき，検出力は0.9996である．
# n=552のとき，検出力は0.9996である．
# n=553のとき，検出力は0.9996である．
# n=554のとき，検出力は0.9996である．
# n=555のとき，検出力は0.9996である．
# n=556のとき，検出力は0.9996である．
# n=557のとき，検出力は0.9996である．
# n=558のとき，検出力は0.9996である．
# n=559のとき，検出力は0.9996である．
# n=560のとき，検出力は0.9996である．
# n=561のとき，検出力は0.9996である．
# n=562のとき，検出力は0.9996である．
# n=563のとき，検出力は0.9996である．
# n=564のとき，検出力は0.9997である．
# n=565のとき，検出力は0.9997である．
# n=566のとき，検出力は0.9997である．
# n=567のとき，検出力は0.9997である．
# n=568のとき，検出力は0.9997である．
# n=569のとき，検出力は0.9997である．
# n=570のとき，検出力は0.9997である．
# n=571のとき，検出力は0.9997である．
# n=572のとき，検出力は0.9997である．
# n=573のとき，検出力は0.9997である．
# n=574のとき，検出力は0.9997である．
# n=575のとき，検出力は0.9997である．
# n=576のとき，検出力は0.9997である．
# n=577のとき，検出力は0.9997である．
# n=578のとき，検出力は0.9997である．
# n=579のとき，検出力は0.9997である．
# n=580のとき，検出力は0.9997である．
# n=581のとき，検出力は0.9997である．
# n=582のとき，検出力は0.9997である．
# n=583のとき，検出力は0.9997である．
# n=584のとき，検出力は0.9998である．
# n=585のとき，検出力は0.9998である．
# n=586のとき，検出力は0.9998である．
# n=587のとき，検出力は0.9998である．
# n=588のとき，検出力は0.9998である．
# n=589のとき，検出力は0.9998である．
# n=590のとき，検出力は0.9998である．
# n=591のとき，検出力は0.9998である．
# n=592のとき，検出力は0.9998である．
# n=593のとき，検出力は0.9998である．
# n=594のとき，検出力は0.9998である．
# n=595のとき，検出力は0.9998である．
# n=596のとき，検出力は0.9998である．
# n=597のとき，検出力は0.9998である．
# n=598のとき，検出力は0.9998である．
# n=599のとき，検出力は0.9998である．
# n=600のとき，検出力は0.9998である．
# n=601のとき，検出力は0.9998である．
# n=602のとき，検出力は0.9998である．
# n=603のとき，検出力は0.9998である．
# n=604のとき，検出力は0.9998である．
# n=605のとき，検出力は0.9998である．
# n=606のとき，検出力は0.9998である．
# n=607のとき，検出力は0.9998である．
# n=608のとき，検出力は0.9998である．
# n=609のとき，検出力は0.9998である．
# n=610のとき，検出力は0.9998である．
# n=611のとき，検出力は0.9998である．
# n=612のとき，検出力は0.9998である．
# n=613のとき，検出力は0.9998である．
# n=614のとき，検出力は0.9998である．
# n=615のとき，検出力は0.9999である．
# n=616のとき，検出力は0.9999である．
# n=617のとき，検出力は0.9999である．
# n=618のとき，検出力は0.9999である．
# n=619のとき，検出力は0.9999である．
# n=620のとき，検出力は0.9999である．
# n=621のとき，検出力は0.9999である．
# n=622のとき，検出力は0.9999である．
# n=623のとき，検出力は0.9999である．
# n=624のとき，検出力は0.9999である．
# n=625のとき，検出力は0.9999である．
# n=626のとき，検出力は0.9999である．
# n=627のとき，検出力は0.9999である．
# n=628のとき，検出力は0.9999である．
# n=629のとき，検出力は0.9999である．
# n=630のとき，検出力は0.9999である．
# n=631のとき，検出力は0.9999である．
# n=632のとき，検出力は0.9999である．
# n=633のとき，検出力は0.9999である．
# n=634のとき，検出力は0.9999である．
# n=635のとき，検出力は0.9999である．
# n=636のとき，検出力は0.9999である．
# n=637のとき，検出力は0.9999である．
# n=638のとき，検出力は0.9999である．
# n=639のとき，検出力は0.9999である．
# n=640のとき，検出力は0.9999である．
# n=641のとき，検出力は0.9999である．
# n=642のとき，検出力は0.9999である．
# n=643のとき，検出力は0.9999である．
# n=644のとき，検出力は0.9999である．
# n=645のとき，検出力は0.9999である．
# n=646のとき，検出力は0.9999である．
# n=647のとき，検出力は0.9999である．
# n=648のとき，検出力は0.9999である．
# n=649のとき，検出力は0.9999である．
# n=650のとき，検出力は0.9999である．
# n=651のとき，検出力は0.9999である．
# n=652のとき，検出力は0.9999である．
# n=653のとき，検出力は0.9999である．
# n=654のとき，検出力は0.9999である．
# n=655のとき，検出力は0.9999である．
# n=656のとき，検出力は0.9999である．
# n=657のとき，検出力は0.9999である．
# n=658のとき，検出力は0.9999である．
# n=659のとき，検出力は0.9999である．
# n=660のとき，検出力は0.9999である．
# n=661のとき，検出力は0.9999である．
# n=662のとき，検出力は0.9999である．
# n=663のとき，検出力は0.9999である．
# n=664のとき，検出力は0.9999である．
# n=665のとき，検出力は0.9999である．
# n=666のとき，検出力は0.9999である．
# n=667のとき，検出力は0.9999である．
# n=668のとき，検出力は0.9999である．
# n=669のとき，検出力は0.9999である．
# n=670のとき，検出力は0.9999である．
# n=671のとき，検出力は0.9999である．
# n=672のとき，検出力は0.9999である．
# n=673のとき，検出力は0.9999である．
# n=674のとき，検出力は0.9999である．
# n=675のとき，検出力は0.9999である．
# n=676のとき，検出力は0.9999である．
# n=677のとき，検出力は0.9999である．
# n=678のとき，検出力は0.9999である．
# n=679のとき，検出力は0.9999である．
# n=680のとき，検出力は0.9999である．
# n=681のとき，検出力は1.0000である．
# n=682のとき，検出力は1.0000である．
# n=683のとき，検出力は1.0000である．
# n=684のとき，検出力は1.0000である．
# n=685のとき，検出力は1.0000である．
# n=686のとき，検出力は1.0000である．
# n=687のとき，検出力は1.0000である．
# n=688のとき，検出力は1.0000である．
# n=689のとき，検出力は1.0000である．
# n=690のとき，検出力は1.0000である．
# n=691のとき，検出力は1.0000である．
# n=692のとき，検出力は1.0000である．
# n=693のとき，検出力は1.0000である．
# n=694のとき，検出力は1.0000である．
# n=695のとき，検出力は1.0000である．
# n=696のとき，検出力は1.0000である．
# n=697のとき，検出力は1.0000である．
# n=698のとき，検出力は1.0000である．
# n=699のとき，検出力は1.0000である．
# n=700のとき，検出力は1.0000である．
# n=701のとき，検出力は1.0000である．
# n=702のとき，検出力は1.0000である．
# n=703のとき，検出力は1.0000である．
# n=704のとき，検出力は1.0000である．
# n=705のとき，検出力は1.0000である．
# n=706のとき，検出力は1.0000である．
# n=707のとき，検出力は1.0000である．
# n=708のとき，検出力は1.0000である．
# n=709のとき，検出力は1.0000である．
# n=710のとき，検出力は1.0000である．
# n=711のとき，検出力は1.0000である．
# n=712のとき，検出力は1.0000である．
# n=713のとき，検出力は1.0000である．
# n=714のとき，検出力は1.0000である．
# n=715のとき，検出力は1.0000である．
# n=716のとき，検出力は1.0000である．
# n=717のとき，検出力は1.0000である．
# n=718のとき，検出力は1.0000である．
# n=719のとき，検出力は1.0000である．
# n=720のとき，検出力は1.0000である．
# n=721のとき，検出力は1.0000である．
# n=722のとき，検出力は1.0000である．
# n=723のとき，検出力は1.0000である．
# n=724のとき，検出力は1.0000である．
# n=725のとき，検出力は1.0000である．
# n=726のとき，検出力は1.0000である．
# n=727のとき，検出力は1.0000である．
# n=728のとき，検出力は1.0000である．
# n=729のとき，検出力は1.0000である．
# n=730のとき，検出力は1.0000である．
# n=731のとき，検出力は1.0000である．
# n=732のとき，検出力は1.0000である．
# n=733のとき，検出力は1.0000である．
# n=734のとき，検出力は1.0000である．
# n=735のとき，検出力は1.0000である．
# n=736のとき，検出力は1.0000である．
# n=737のとき，検出力は1.0000である．
# n=738のとき，検出力は1.0000である．
# n=739のとき，検出力は1.0000である．
# n=740のとき，検出力は1.0000である．
# n=741のとき，検出力は1.0000である．
# n=742のとき，検出力は1.0000である．
# n=743のとき，検出力は1.0000である．
# n=744のとき，検出力は1.0000である．
# n=745のとき，検出力は1.0000である．
# n=746のとき，検出力は1.0000である．
# n=747のとき，検出力は1.0000である．
# n=748のとき，検出力は1.0000である．
# n=749のとき，検出力は1.0000である．
# n=750のとき，検出力は1.0000である．
# n=751のとき，検出力は1.0000である．
# n=752のとき，検出力は1.0000である．
# n=753のとき，検出力は1.0000である．
# n=754のとき，検出力は1.0000である．
# n=755のとき，検出力は1.0000である．
# n=756のとき，検出力は1.0000である．
# n=757のとき，検出力は1.0000である．
# n=758のとき，検出力は1.0000である．
# n=759のとき，検出力は1.0000である．
# n=760のとき，検出力は1.0000である．
# n=761のとき，検出力は1.0000である．
# n=762のとき，検出力は1.0000である．
# n=763のとき，検出力は1.0000である．
# n=764のとき，検出力は1.0000である．
# n=765のとき，検出力は1.0000である．
# n=766のとき，検出力は1.0000である．
# n=767のとき，検出力は1.0000である．
# n=768のとき，検出力は1.0000である．
# n=769のとき，検出力は1.0000である．
# n=770のとき，検出力は1.0000である．
# n=771のとき，検出力は1.0000である．
# n=772のとき，検出力は1.0000である．
# n=773のとき，検出力は1.0000である．
# n=774のとき，検出力は1.0000である．
# n=775のとき，検出力は1.0000である．
# n=776のとき，検出力は1.0000である．
# n=777のとき，検出力は1.0000である．
# n=778のとき，検出力は1.0000である．
# n=779のとき，検出力は1.0000である．
# n=780のとき，検出力は1.0000である．
# n=781のとき，検出力は1.0000である．
# n=782のとき，検出力は1.0000である．
# n=783のとき，検出力は1.0000である．
# n=784のとき，検出力は1.0000である．
# n=785のとき，検出力は1.0000である．
# n=786のとき，検出力は1.0000である．
# n=787のとき，検出力は1.0000である．
# n=788のとき，検出力は1.0000である．
# n=789のとき，検出力は1.0000である．
# n=790のとき，検出力は1.0000である．
# n=791のとき，検出力は1.0000である．
# n=792のとき，検出力は1.0000である．
# n=793のとき，検出力は1.0000である．
# n=794のとき，検出力は1.0000である．
# n=795のとき，検出力は1.0000である．
# n=796のとき，検出力は1.0000である．
# n=797のとき，検出力は1.0000である．
# n=798のとき，検出力は1.0000である．
# n=799のとき，検出力は1.0000である．
# n=800のとき，検出力は1.0000である．
# n=801のとき，検出力は1.0000である．
# n=802のとき，検出力は1.0000である．
# n=803のとき，検出力は1.0000である．
# n=804のとき，検出力は1.0000である．
# n=805のとき，検出力は1.0000である．
# n=806のとき，検出力は1.0000である．
# n=807のとき，検出力は1.0000である．
# n=808のとき，検出力は1.0000である．
# n=809のとき，検出力は1.0000である．
# n=810のとき，検出力は1.0000である．
# n=811のとき，検出力は1.0000である．
# n=812のとき，検出力は1.0000である．
# n=813のとき，検出力は1.0000である．
# n=814のとき，検出力は1.0000である．
# n=815のとき，検出力は1.0000である．
# n=816のとき，検出力は1.0000である．
# n=817のとき，検出力は1.0000である．
# n=818のとき，検出力は1.0000である．
# n=819のとき，検出力は1.0000である．
# n=820のとき，検出力は1.0000である．
# n=821のとき，検出力は1.0000である．
# n=822のとき，検出力は1.0000である．
# n=823のとき，検出力は1.0000である．
# n=824のとき，検出力は1.0000である．
# n=825のとき，検出力は1.0000である．
# n=826のとき，検出力は1.0000である．
# n=827のとき，検出力は1.0000である．
# n=828のとき，検出力は1.0000である．
# n=829のとき，検出力は1.0000である．
# n=830のとき，検出力は1.0000である．
# n=831のとき，検出力は1.0000である．
# n=832のとき，検出力は1.0000である．
# n=833のとき，検出力は1.0000である．
# n=834のとき，検出力は1.0000である．
# n=835のとき，検出力は1.0000である．
# n=836のとき，検出力は1.0000である．
# n=837のとき，検出力は1.0000である．
# n=838のとき，検出力は1.0000である．
# n=839のとき，検出力は1.0000である．
# n=840のとき，検出力は1.0000である．
# n=841のとき，検出力は1.0000である．
# n=842のとき，検出力は1.0000である．
# n=843のとき，検出力は1.0000である．
# n=844のとき，検出力は1.0000である．
# n=845のとき，検出力は1.0000である．
# n=846のとき，検出力は1.0000である．
# n=847のとき，検出力は1.0000である．
# n=848のとき，検出力は1.0000である．
# n=849のとき，検出力は1.0000である．
# n=850のとき，検出力は1.0000である．
# n=851のとき，検出力は1.0000である．
# n=852のとき，検出力は1.0000である．
# n=853のとき，検出力は1.0000である．
# n=854のとき，検出力は1.0000である．
# n=855のとき，検出力は1.0000である．
# n=856のとき，検出力は1.0000である．
# n=857のとき，検出力は1.0000である．
# n=858のとき，検出力は1.0000である．
# n=859のとき，検出力は1.0000である．
# n=860のとき，検出力は1.0000である．
# n=861のとき，検出力は1.0000である．
# n=862のとき，検出力は1.0000である．
# n=863のとき，検出力は1.0000である．
# n=864のとき，検出力は1.0000である．
# n=865のとき，検出力は1.0000である．
# n=866のとき，検出力は1.0000である．
# n=867のとき，検出力は1.0000である．
# n=868のとき，検出力は1.0000である．
# n=869のとき，検出力は1.0000である．
# n=870のとき，検出力は1.0000である．
# n=871のとき，検出力は1.0000である．
# n=872のとき，検出力は1.0000である．
# n=873のとき，検出力は1.0000である．
# n=874のとき，検出力は1.0000である．
# n=875のとき，検出力は1.0000である．
# n=876のとき，検出力は1.0000である．
# n=877のとき，検出力は1.0000である．
# n=878のとき，検出力は1.0000である．
# n=879のとき，検出力は1.0000である．
# n=880のとき，検出力は1.0000である．
# n=881のとき，検出力は1.0000である．
# n=882のとき，検出力は1.0000である．
# n=883のとき，検出力は1.0000である．
# n=884のとき，検出力は1.0000である．
# n=885のとき，検出力は1.0000である．
# n=886のとき，検出力は1.0000である．
# n=887のとき，検出力は1.0000である．
# n=888のとき，検出力は1.0000である．
# n=889のとき，検出力は1.0000である．
# n=890のとき，検出力は1.0000である．
# n=891のとき，検出力は1.0000である．
# n=892のとき，検出力は1.0000である．
# n=893のとき，検出力は1.0000である．
# n=894のとき，検出力は1.0000である．
# n=895のとき，検出力は1.0000である．
# n=896のとき，検出力は1.0000である．
# n=897のとき，検出力は1.0000である．
# n=898のとき，検出力は1.0000である．
# n=899のとき，検出力は1.0000である．
# n=900のとき，検出力は1.0000である．
# n=901のとき，検出力は1.0000である．
# n=902のとき，検出力は1.0000である．
# n=903のとき，検出力は1.0000である．
# n=904のとき，検出力は1.0000である．
# n=905のとき，検出力は1.0000である．
# n=906のとき，検出力は1.0000である．
# n=907のとき，検出力は1.0000である．
# n=908のとき，検出力は1.0000である．
# n=909のとき，検出力は1.0000である．
# n=910のとき，検出力は1.0000である．
# n=911のとき，検出力は1.0000である．
# n=912のとき，検出力は1.0000である．
# n=913のとき，検出力は1.0000である．
# n=914のとき，検出力は1.0000である．
# n=915のとき，検出力は1.0000である．
# n=916のとき，検出力は1.0000である．
# n=917のとき，検出力は1.0000である．
# n=918のとき，検出力は1.0000である．
# n=919のとき，検出力は1.0000である．
# n=920のとき，検出力は1.0000である．
# n=921のとき，検出力は1.0000である．
# n=922のとき，検出力は1.0000である．
# n=923のとき，検出力は1.0000である．
# n=924のとき，検出力は1.0000である．
# n=925のとき，検出力は1.0000である．
# n=926のとき，検出力は1.0000である．
# n=927のとき，検出力は1.0000である．
# n=928のとき，検出力は1.0000である．
# n=929のとき，検出力は1.0000である．
# n=930のとき，検出力は1.0000である．
# n=931のとき，検出力は1.0000である．
# n=932のとき，検出力は1.0000である．
# n=933のとき，検出力は1.0000である．
# n=934のとき，検出力は1.0000である．
# n=935のとき，検出力は1.0000である．
# n=936のとき，検出力は1.0000である．
# n=937のとき，検出力は1.0000である．
# n=938のとき，検出力は1.0000である．
# n=939のとき，検出力は1.0000である．
# n=940のとき，検出力は1.0000である．
# n=941のとき，検出力は1.0000である．
# n=942のとき，検出力は1.0000である．
# n=943のとき，検出力は1.0000である．
# n=944のとき，検出力は1.0000である．
# n=945のとき，検出力は1.0000である．
# n=946のとき，検出力は1.0000である．
# n=947のとき，検出力は1.0000である．
# n=948のとき，検出力は1.0000である．
# n=949のとき，検出力は1.0000である．
# n=950のとき，検出力は1.0000である．
# n=951のとき，検出力は1.0000である．
# n=952のとき，検出力は1.0000である．
# n=953のとき，検出力は1.0000である．
# n=954のとき，検出力は1.0000である．
# n=955のとき，検出力は1.0000である．
# n=956のとき，検出力は1.0000である．
# n=957のとき，検出力は1.0000である．
# n=958のとき，検出力は1.0000である．
# n=959のとき，検出力は1.0000である．
# n=960のとき，検出力は1.0000である．
# n=961のとき，検出力は1.0000である．
# n=962のとき，検出力は1.0000である．
# n=963のとき，検出力は1.0000である．
# n=964のとき，検出力は1.0000である．
# n=965のとき，検出力は1.0000である．
# n=966のとき，検出力は1.0000である．
# n=967のとき，検出力は1.0000である．
# n=968のとき，検出力は1.0000である．
# n=969のとき，検出力は1.0000である．
# n=970のとき，検出力は1.0000である．
# n=971のとき，検出力は1.0000である．
# n=972のとき，検出力は1.0000である．
# n=973のとき，検出力は1.0000である．
# n=974のとき，検出力は1.0000である．
# n=975のとき，検出力は1.0000である．
# n=976のとき，検出力は1.0000である．
# n=977のとき，検出力は1.0000である．
# n=978のとき，検出力は1.0000である．
# n=979のとき，検出力は1.0000である．
# n=980のとき，検出力は1.0000である．
# n=981のとき，検出力は1.0000である．
# n=982のとき，検出力は1.0000である．
# n=983のとき，検出力は1.0000である．
# n=984のとき，検出力は1.0000である．
# n=985のとき，検出力は1.0000である．
# n=986のとき，検出力は1.0000である．
# n=987のとき，検出力は1.0000である．
# n=988のとき，検出力は1.0000である．
# n=989のとき，検出力は1.0000である．
# n=990のとき，検出力は1.0000である．
# n=991のとき，検出力は1.0000である．
# n=992のとき，検出力は1.0000である．
# n=993のとき，検出力は1.0000である．
# n=994のとき，検出力は1.0000である．
# n=995のとき，検出力は1.0000である．
# n=996のとき，検出力は1.0000である．
# n=997のとき，検出力は1.0000である．
# n=998のとき，検出力は1.0000である．
# n=999のとき，検出力は1.0000である．

# %% [markdown]
# # 対応のある検定
#
# 配布ファイル`2026_02_Tempo_Kanto.csv`に記録されている，2026年2月の東京，横浜，さいたま、千葉の日毎平均気温のデータをもとに，この4地点の2月の気温について，差があるかどうか判断したい．
#
# 0. まずは，変数を標準化してt統計量をつくるための関数を用意しておく．
# $$
# t = \frac{m}{\sqrt{v/\nu}} \quad (\text{$m$: 平均，$v$: 標本分散，$\nu$: 標本の大きさ})
# $$

# %%
def t_val(m,v,nu): # m: 平均，v: 標本分散，nu: 標本の大きさ
  return m / np.sqrt(v / nu)

# %% [markdown]
# 1. まず，`df1`に配布ファイル`2026_02_Tempo_Kanto.csv`のデータを読み込もう．
# データの読み込みには，以下のコードを利用せよ．
# ```
# df1 = pd.read_csv("/content/drive/MyDrive/.../2026_02_Tempo_Kanto.csv")
# ```
# ここでの`"/content/drive/MyDrive/.../12026_02_Tempo_Kanto.csv"`は，配布された`2026_02_Tempo_Kanto.csv`のドライブ上の保存場所（パス）と配布データセットのファイル名を表す．
# 各自で適切なものを設定すること．
#
# 正しく読み込めているかを，`df1`の最初の数行を出力することで確認せよ．
# コードは
# ```
# df1.head()
# ```
# が利用できる．

# %%
df1 = pd.read_csv("2026_02_Tempo_Kanto.csv")
df1.head()
# Out:
#    2026_02   東京   横浜  さいたま   千葉
# 0        1  5.5  6.2   3.5  5.9
# 1        2  6.4  6.9   4.7  6.6
# 2        3  5.8  6.7   4.2  6.1
# 3        4  6.3  6.8   4.0  6.8
# 4        5  7.8  8.4   5.8  8.3

# %% [markdown]
# 2. `df1`に，東京と横浜の気温差
# $$
# (\text{東京}) - (\text{横浜})
# $$
# の列を追加せよ．
# 列のタイトルは，「東京vs横浜」とせよ．
#
#   ヒント:
#   1. データフレーム`df1`の「東京」列のデータを取り出すには，`df1["東京"]`とすればよい．
#   2. データフレーム`df1`に，「東京」列と「横浜」列の各データの和の列を「東京+横浜」という列タイトルで追加するには，
#   ```
#   df1["東京+横浜"] = df1["東京"] + df1["横浜"]
#   ```
#   とすればよい．

# %%
df1["東京vs横浜"] = df1["東京"] - df1["横浜"]
df1.head()
# Out:
#    2026_02   東京   横浜  さいたま   千葉  東京vs横浜
# 0        1  5.5  6.2   3.5  5.9    -0.7
# 1        2  6.4  6.9   4.7  6.6    -0.5
# 2        3  5.8  6.7   4.2  6.1    -0.9
# 3        4  6.3  6.8   4.0  6.8    -0.5
# 4        5  7.8  8.4   5.8  8.3    -0.6

# %% [markdown]
# 3. データフレーム`df1`の「東京vs横浜」列のデータの平均，不偏標本分散，標本の大きさをそれぞれ`mean_tokyo_yokohama`，`var_tokyo_yokohama`，`len_tokyo_yokohama`に格納し，その結果を表示せよ．
#
#   ヒント:
#   1. データの平均を求めるには，`np.mean(データ)`関数が使える．
#   2. データの分散を求めるには，`np.var(データ,ddof=r)`関数が使える．
#   ここで，`ddof`の値は，$(\text{標本数})-(\text{自由度})$，すなわち束縛条件の数である．
#   今回は，`ddof=1`とする．
#   3. 標本の大きさを求めるには，`len(データ)`が使える．

# %%
mean_tokyo_yokohama, var_tokyo_yokohama, len_tokyo_yokohama = np.mean(df1["東京vs横浜"]), np.var(df1["東京vs横浜"],ddof=1),len(df1)
print("東京と横浜の気温差の平均は{:.4f}，不偏標本分散は{:.4f}，標本数は{}である．".format(mean_tokyo_yokohama,var_tokyo_yokohama,len_tokyo_yokohama))
# Out:
# 東京と横浜の気温差の平均は-0.4893，不偏標本分散は0.2440，標本数は28である．

# %% [markdown]
# 4. 東京と横浜に気温差が認められるか否かについて，気温差が正規分布に従うと仮定し，
# $$
# H_0 \colon \mu_d = 0, \quad H_1 \colon \mu_d \neq 0 \qquad (\text{$\mu_d$は気温差の平均})
# $$
# として，有意水準$5\%$の両側t検定を行え．
# 検定の根拠となるt統計量，およびt分布の上側パーセント点も表示すること．
#
#   ヒント:
#   1. 東京と横浜の気温差のt統計量は，上で定義した`t_val()`を使え．
#   2. （両側検定であるから）自由度`n-1`のt分布の上側$100 \alpha / 2\%$点の座標を与える関数は，
#   ```
#   t_ppt = stats.t.ppf(1 - a/2, n - 1)
#   ```
#   を利用せよ．

# %%
t_tokyo_yokohama = t_val(mean_tokyo_yokohama, var_tokyo_yokohama, len_tokyo_yokohama)
t_ppt = stats.t.ppf(0.975,len_tokyo_yokohama-1)
print("東京と横浜の2月の気温差のt統計量は{:.4f}であり，自由度{}のt分布における上側2.5%点は{:.4f}である．".format(t_tokyo_yokohama, len_tokyo_yokohama-1, t_ppt))

if abs(t_tokyo_yokohama) < t_ppt:
  print("H_0は棄却されず，東京と横浜の2月の日毎平均気温に差はあるとはいえない．")
else:
  print("H_0は棄却され，東京と横浜の2月の日毎平均気温に差はあるといえる．")
# Out:
# 東京と横浜の2月の気温差のt統計量は-5.2419であり，自由度27のt分布における上側2.5%点は2.0518である．
# H_0は棄却され，東京と横浜の2月の日毎平均気温に差はあるといえる．

# %% [markdown]
# 5. 同様の手続きにより，東京と横浜に気温差があるか否かについて，
# $$
# H_0 \colon \mu_d = 0, \quad H_1 \colon \mu_d \neq 0
# $$
# とした有意水準$5%$の両側t検定を行え．

# %%
# 東京と千葉の気温差をdf1の「東京vs千葉」列に格納する
df1["東京vs千葉"] = df1["東京"] - df1["千葉"]
df1.head()
# Out:
#    2026_02   東京   横浜  さいたま   千葉  東京vs横浜  東京vs千葉
# 0        1  5.5  6.2   3.5  5.9    -0.7    -0.4
# 1        2  6.4  6.9   4.7  6.6    -0.5    -0.2
# 2        3  5.8  6.7   4.2  6.1    -0.9    -0.3
# 3        4  6.3  6.8   4.0  6.8    -0.5    -0.5
# 4        5  7.8  8.4   5.8  8.3    -0.6    -0.5

# %%
# 東京と千葉の気温差の平均，分散，標本の大きさをそれぞれの変数に格納する

mean_tokyo_chiba, var_tokyo_chiba, len_tokyo_chiba = np.mean(df1["東京vs千葉"]), np.var(df1["東京vs千葉"],ddof=1), len(df1)

# t統計量を求める（上側2.5%点はすでに横浜との対比のところで作ったt_pptを利用すればよい）

t_tokyo_chiba = t_val(mean_tokyo_chiba, var_tokyo_chiba, len_tokyo_chiba)

# 統計b量を比較し，検定結果を表示する

print("東京と千葉の2月の気温差のt統計量は{:.4f}であり，自由度{}のt分布における上側2.5%点は{:.4f}である．".format(t_tokyo_chiba, len_tokyo_chiba-1, t_ppt))

if abs(t_tokyo_chiba) < t_ppt:
  print("H_0は棄却されず，東京と千葉の2月の日毎平均気温に差はあるとはいえない．")
else:
  print("H_0は棄却され，東京と千葉の2月の日毎平均気温に差はあるといえる．")
# Out:
# 東京と千葉の2月の気温差のt統計量は-4.8987であり，自由度27のt分布における上側2.5%点は2.0518である．
# H_0は棄却され，東京と千葉の2月の日毎平均気温に差はあるといえる．

# %%
# 横浜と千葉の気温差をdf1の「横浜vs千葉」列に格納する
df1["横浜vs千葉"] = df1["横浜"] - df1["千葉"]
df1.head()
# Out:
#    2026_02   東京   横浜  さいたま   千葉  東京vs横浜  東京vs千葉  横浜vs千葉
# 0        1  5.5  6.2   3.5  5.9    -0.7    -0.4     0.3
# 1        2  6.4  6.9   4.7  6.6    -0.5    -0.2     0.3
# 2        3  5.8  6.7   4.2  6.1    -0.9    -0.3     0.6
# 3        4  6.3  6.8   4.0  6.8    -0.5    -0.5     0.0
# 4        5  7.8  8.4   5.8  8.3    -0.6    -0.5     0.1

# %%
# 横浜と千葉の気温差の平均，分散，標本の大きさをそれぞれの変数に格納する

mean_yokohama_chiba, var_yokohama_chiba, len_yokohama_chiba = np.mean(df1["横浜vs千葉"]), np.var(df1["横浜vs千葉"],ddof=1), len(df1)

# t統計量を求める（上側2.5%点はすでに横浜との対比のところで作ったt_pptを利用すればよい）

t_yokohama_chiba = t_val(mean_yokohama_chiba, var_yokohama_chiba, len_yokohama_chiba)

# 統計b量を比較し，検定結果を表示する

print("横浜と千葉の2月の気温差のt統計量は{:.4f}であり，自由度{}のt分布における上側2.5%点は{:.4f}である．".format(t_yokohama_chiba, len_yokohama_chiba-1, t_ppt))

if abs(t_yokohama_chiba) < t_ppt:
  print("H_0は棄却されず，横浜と千葉の2月の日毎平均気温に差はあるとはいえない．")
else:
  print("H_0は棄却され，横浜と千葉の2月の日毎平均気温に差はあるといえる．")
# Out:
# 横浜と千葉の2月の気温差のt統計量は-0.7461であり，自由度27のt分布における上側2.5%点は2.0518である．
# H_0は棄却されず，横浜と千葉の2月の日毎平均気温に差はあるとはいえない．

# %% [markdown]
# # Welch's t-Test
#
# 配布ファイル`116_AvsB.csv`には，40人にA，Bの2種類の問題集を無作為に割り当てて使用してもらい，使用の前後に受験したテストの成績を記録している（データは架空です）．

# %% [markdown]
# 1. まず，`df2`に配布ファイル`116_AvsB.csv`のデータを読み込もう．
# データの読み込みには，以下のコードを利用せよ．
# ```
# df2 = pd.read_csv("/content/drive/MyDrive/.../116_AvsB.csv")
# ```
# ここでの`"/content/drive/MyDrive/.../116_AvsB.csv"`は，配布された`116_AvsB.csv`のドライブ上の保存場所（パス）と配布データセットのファイル名を表す．
# 各自で適切なものを設定すること．
#
# 正しく読み込めているかを，`df2`の最初の数行を出力することで確認せよ．

# %%
df2 = pd.read_csv("116_AvsB.csv")
df2.head()
# Out:
#    ID  事前テスト 使用問題集  事後テスト
# 0   1     57     A     78
# 1   2     54     B     65
# 2   3     52     A     74
# 3   4     51     A     69
# 4   5     54     A     77

# %% [markdown]
# 2. データフレーム`df2`に，「差分」という列タイトルで，「事前テスト」と「事後テスト」のそれぞれの差を計算した列を作れ．

# %%
df2["差分"] = df2["事後テスト"] - df2["事前テスト"]
df2.head()
# Out:
#    ID  事前テスト 使用問題集  事後テスト  差分
# 0   1     57     A     78  21
# 1   2     54     B     65  11
# 2   3     52     A     74  22
# 3   4     51     A     69  18
# 4   5     54     A     77  23

# %% [markdown]
# 3. データフレーム`df2`のデータのうち，使用問題集がAであるものBであるもののみを抜き出し，それぞれデータフレーム`df2_A`，`df2_B`に格納せよ．
#
#   ヒント:
#   1. データフレームの中から特定の条件を満たす行のみを取り出すには，`df2[条件]`を利用する．今回の場合，例えば「使用問題集」列にAが入力されている行のみを抜き出すので，条件は
#   ```
#   df2["使用問題集"] == "A"
#   ```
#   を用いればよい．
#   2. 正しく抜き出せているかを見るには，`df2_A.head()`などを実行し，`df2_A`の中身を見るとよい．

# %%
df2_A = df2[df2["使用問題集"] == "A"]
df2_B = df2[df2["使用問題集"] == "B"]

# %% [markdown]
# 4. データフレーム`df2_A`，`df2_B`における「差分」列のデータの平均，不偏標本分散，標本の大きさを取り出し，それぞれ`mean_X`，`var_X`，`len_X`（`X`は`A`，`B`のいずれか）とし，それらのデータを出力せよ．
# 分散計算において，自由度を加味することを忘れないように注意せよ．

# %%
mean_A, var_A, len_A = np.mean(df2_A["差分"]), np.var(df2_A["差分"],ddof=1), len(df2_A)
mean_B, var_B, len_B = np.mean(df2_B["差分"]), np.var(df2_B["差分"],ddof=1), len(df2_B)
print("問題集Aを利用した群の平均は{:.4f}，不偏標本分散は{:.4f}，標本の大きさは{}である．".format(mean_A,var_A,len_A))
print("問題集Bを利用した群の平均は{:.4f}，不偏標本分散は{:.4f}，標本の大きさは{}である．".format(mean_B,var_B,len_B))
# Out:
# 問題集Aを利用した群の平均は16.6000，不偏標本分散は46.5684，標本の大きさは20である．
# 問題集Bを利用した群の平均は19.9000，不偏標本分散は34.5158，標本の大きさは20である．

# %% [markdown]
# 5. 問題集Aを利用した群と問題集Bを利用した群の平均の差の分散を求め，`var_com`に格納せよ．
# また，この計算結果をもとに，平均の差のt統計量`t_AB`を計算し，その値を出力せよ．

# %%
var_com = var_A / len_A + var_B / len_B
t_AB = (mean_A - mean_B) / np.sqrt(var_com)
t_AB
# Out:
# np.float64(-1.638931458635994)

# %% [markdown]
# 6. t検定を行うために，ウェルチの近似式から計算される値`nu_welch`を計算し，`nu_welch`に最も近い整数`nu_star`を求めよ．
# ここで求めた`nu_star`が，次に行うt検定の自由度を与える．

# %%
nu_welch = var_com**2 / ((var_A/len_A)**2/(len_A-1) + (var_B/len_B)**2/(len_B-1))
nu_star = round(nu_welch)
nu_star
# Out:
# 37

# %% [markdown]
# 7. 上で求めた自由度`nu_star`を用いて，問題集Aを用いたときの成績の上昇具合$\mu_A$，問題集Bを用いた時の成績の上昇具合$\mu_B$について，
# $$
# H_0 \colon \mu_A - \mu_B = 0, \quad H_1 \colon \mu_A - \mu_B \neq 0
# $$
# として有意水準$5\%$の両側t検定（Welch検定）を行え．

# %%
t_AB_ppt = stats.t.ppf(0.975,nu_star)

print("t統計量は{:.4f}であり，自由度{}のt分布の上側2.5%点は{:.4f}である．".format(t_AB,nu_star,t_AB_ppt))

if abs(t_AB) < t_AB_ppt:
  print("H_0は棄却されず，使用問題集AとBによる成績の上昇具合に差はあるとはいえない．")
else:
  print("H_0は棄却され，使用問題集AとBによる成績の上昇具合に差はあるといえる．")
# Out:
# t統計量は-1.6389であり，自由度37のt分布の上側2.5%点は2.0262である．
# H_0は棄却されず，使用問題集AとBによる成績の上昇具合に差はあるとはいえない．

# %% [markdown]
# 8. 効果量を`3`（つまり$3$点以上差があれば2つの問題集に差があるとみなすに十分でである）として，この検定の検定力を求めよ．
# 今回は両側検定を行っているので，$H_0$の採択域に注意せよ．

# %%
d = 3
t_border = stats.t.ppf(0.975,nu_star)
b = stats.t.cdf(t_border,nu_star,loc=d) - stats.t.cdf(-t_border,nu_star,loc=d)
print("この検定の検出力は{:.4f}である．".format(1-b))
# Out:
# この検定の検出力は0.8318である．
